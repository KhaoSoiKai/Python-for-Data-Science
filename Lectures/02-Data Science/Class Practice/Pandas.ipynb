# %%
import pandas as pd

pd.__version__
# Out:
# '1.4.3'

# %%
df = pd.read_csv("howlongwelive.csv")

df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
print(df.shape)
df.info
developing_countries = df['Status'] == 'Developing'
developed_countries = df['Status'] == 'Developed'

print("Developing countries: ", len(developed_countries))
print("Developed countries: ", (df['Status'].shape[0] ))
# Out:
# (2938, 22)
# Developing countries:  2938
# Developed countries:  2938

# %%
df['Alcohol'].max()

df.Country[df['Alcohol'] > df['Alcohol'].median()].unique().shape
# Out:
# (106,)

# %%
df.Country[df['Schooling'] > df['Schooling'].median()].unique().shape

df.Country[df['GDP'] > df['GDP'].median()].unique().shape

df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
import seaborn as sns

# seaborn is built on top of matplotlib
sns.countplot(df.Status)
# Out:
# /Users/mehul.parmar/Library/Python/3.8/lib/python/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Status', ylabel='count'>

# %%
sns.distplot(df.GDP)
# Out:
# /Users/mehul.parmar/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='GDP', ylabel='Density'>

# %%
# df.columns
df = df.rename(
    columns = {'Life expectancy ': 'life-exp', 'Income composition of resources': 'income'}
)
df.head()
# Out:
#        Country  Year      Status  life-exp  Adult Mortality  infant deaths  \
# 0  Afghanistan  2015  Developing      65.0            263.0             62
# 1  Afghanistan  2014  Developing      59.9            271.0             64
# 2  Afghanistan  2013  Developing      59.9            268.0             66
# 3  Afghanistan  2012  Developing      59.5            272.0             69
# 4  Afghanistan  2011  Developing      59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles   ...  Polio  \
# 0     0.01               71.279624         65.0      1154  ...    6.0
# 1     0.01               73.523582         62.0       492  ...   58.0
# 2     0.01               73.219243         64.0       430  ...   62.0
# 3     0.01               78.184215         67.0      2787  ...   67.0
# 4     0.01                7.097109         68.0      3013  ...   68.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
# df[0] = df[0].str.strip()

df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'life-exp', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'income', 'Schooling'],
#       dtype='object')

# %%
sns.boxplot(x = df['Status'], y = df['life-exp'])
# Out:
# <AxesSubplot:xlabel='Status', ylabel='life-exp'>

# %%
sns.scatterplot(x = df['Total expenditure'], y = df['life-exp'], hue= df['Status'])
# Out:
# <AxesSubplot:xlabel='Total expenditure', ylabel='life-exp'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (15,8))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>
